# %% [markdown]
# ##### בסיעתא דשמיא

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv('./data/dataset.csv')
df.head()
# Out:
#    Unnamed: 0  pixel_0  pixel_1  pixel_2  pixel_3  pixel_4  pixel_5  pixel_6  \
# 0           0       59       62       63       43       46       45       50
# 1           1      154      177      187      126      137      136      105
# 2           2      255      255      255      253      253      253      253
# 3           3       28       25       10       37       34       19       38
# 4           4      170      180      198      168      178      196      177
#
#    pixel_7  pixel_8  ...  pixel_3064  pixel_3065  pixel_3066  pixel_3067  \
# 0       48       43  ...         184         140         151         118
# 1      104       95  ...         133         139         143         134
# 2      253      253  ...          85          83          79          85
# 3       35       20  ...          47          28          63          56
# 4      185      203  ...          79          82          71          75
#
# ...

# %%
# X - pixels of images
pixels = [col for col in df.columns if col.startswith('pixel')]
X = df[pixels]

# %%
# Y - labels
y = df['label']

# %%
# const a random_state variable
random_state = 0
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=random_state)

# %%
X_train.shape
# Out:
# (51750, 3072)

# %%
X_test.shape
# Out:
# (17250, 3072)

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# StandardScaler() - Standardize features by removing the mean and scaling to unit variance.

# %%
scaler = MinMaxScaler()

# %%
X_train_norm = pd.DataFrame(scaler.fit_transform(X_train_norm), columns=pixels)

# %%
X_train_norm.head()
# Out:
#     pixel_0   pixel_1   pixel_2   pixel_3   pixel_4   pixel_5   pixel_6  \
# 0  0.760784  0.760784  0.760784  0.788235  0.788235  0.788235  0.815686
# 1  0.607843  0.713725  0.909804  0.596078  0.698039  0.894118  0.596078
# 2  0.262745  0.364706  0.396078  0.223529  0.290196  0.309804  0.164706
# 3  0.996078  0.996078  0.996078  0.988235  0.988235  0.988235  0.992157
# 4  0.905882  0.929412  0.921569  0.901961  0.925490  0.917647  0.901961
#
#     pixel_7   pixel_8   pixel_9  ...  pixel_3062  pixel_3063  pixel_3064  \
# 0  0.815686  0.815686  0.831373  ...    0.639216    0.521569    0.525490
# 1  0.698039  0.894118  0.596078  ...    0.305882    0.227451    0.278431
# 2  0.231373  0.223529  0.149020  ...    0.490196    0.133333    0.309804
# 3  0.992157  0.992157  0.992157  ...    0.647059    0.584314    0.600000
# 4  0.925490  0.917647  0.901961  ...    0.949020    0.945098    0.952941
#
#    pixel_3065  pixel_3066  pixel_3067  pixel_3068  pixel_3069  pixel_3070  \
# ...

# %%
standard_scaler = StandardScaler()

# %%
df_standarized = pd.DataFrame(standard_scaler.fit_transform(X_train_norm), columns=pixels)
df_standarized.head()
# Out:
#     pixel_0   pixel_1   pixel_2   pixel_3   pixel_4   pixel_5   pixel_6  \
# 0  0.852538  0.786366  0.752200  0.963972  0.898745  0.852355  1.049553
# 1  0.327671  0.623465  1.218021  0.296143  0.582490  1.186660  0.284329
# 2 -0.856643 -0.584720 -0.387836 -0.998626 -0.847535 -0.658209 -1.218789
# 3  1.660025  1.600873  1.487707  1.659059  1.600008  1.483820  1.664464
# 4  1.350488  1.370096  1.254797  1.359218  1.380004  1.260950  1.350176
#
#     pixel_7   pixel_8   pixel_9  ...  pixel_3062  pixel_3063  pixel_3064  \
# 0  0.986774  0.931843  1.100116  ...    0.785140    0.120679    0.162811
# 1  0.573060  1.179929  0.277623  ...   -0.504404   -1.032392   -0.843543
# 2 -1.068005 -0.941206 -1.285113  ...    0.208638   -1.401374   -0.715752
# 3  1.607344  1.490036  1.662153  ...    0.815482    0.366667    0.466315
# 4  1.372907  1.254355  1.346864  ...    1.983657    1.781101    1.903964
#
#    pixel_3065  pixel_3066  pixel_3067  pixel_3068  pixel_3069  pixel_3070  \
# ...

# %%
# Normalization & Standarization for test set
